# %% [markdown]
# # Tensorflow

# %% [markdown]
# ## 基本介绍

# %% [markdown]
# 深度学习框架，支持python、c++等流行语言，可方便移植到各种平台（手机、windows、linux等）进行部署，有强大的图形可视化能力，所以与其他框架相比各占优势。

# %% [markdown]
# ## Titanic

# %%
import pandas as pd

data = pd.read_csv("titanic/train.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### 预处理

# %%
data['Sex'] = data['Sex'].apply(lambda x:1 if x=='male' else 0)

# %%
# 缺失值
data = data.fillna(0)
dataset_X = data[['Sex','Age','Pclass','SibSp','Parch','Fare']]
dataset_X = dataset_X.values()

data['Deceased'] = data['Survived'].apply(lambda x:int(not x))
dataset_Y = data[['Survived','Deceased']]
dataset_Y = dataset_Y.values()
# Out:
# D:\software\anaconda\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# D:\software\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(dataset_X,dataset_Y,test_size=0.2,random_state = 42)
