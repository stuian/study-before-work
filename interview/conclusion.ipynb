# %% [markdown]
# ### 周总结

# %% [markdown]
# ## 20210301-20210307

# %% [markdown]
# - Python100天： 01-09
# - Leetcode： 提交3道
# - 小程序：完成滑动推荐功能
# - 李宏毅机器学习：01-02

# %% [markdown]
# ## 20210308-20210314

# %% [markdown]
# - 李宏毅机器学习：03-04
# - 刷题：提交18道
# - 写简历
# - 看面经
# - github机器学习之逻辑回归

# %% [markdown]
# > 效率太低，一周做的事情太少

# %% [markdown]
# ## 20210315-20210321

# %% [markdown]
# - 牛客刷题10噵
# - 机器学习评估那一章（星期一看的，星期天就忘光了，吐了）
# - 时间序列研究总结（主要是聚类）
# - C语言重学（20+课）
# - 熟悉简历
# - 组会ppt
# - 投简历

# %% [markdown]
# > 刷的题都要忘光了
