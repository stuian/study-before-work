# %% [markdown]
# # 待投

# %% [markdown]
# ## 小红书（21的，没有22）

# %% [markdown]
# 岗位：后端开发
#
# 要求：
#
# 1、全日制计算机相关专业本科及以上学历；
# 2、擅长任意一种语言，包括但不限于：C/C++/Java/Python/Go/PHP/Javascript;
# 3、熟悉常用数据结构与算法、计算机网络、操作系统；
# 4、掌握数据库基本理论及基础的应用实践；
# 5、了解TCP/IP、HTTP、 Linux等基础。
#
# 岗位：算法工程师（机器学习）
#
# 任职要求
# 1、与其他的工程师一同分析，解决搜索、推荐、广告等业务上的难题；
# 2、应用数据分析、统计理论、机器学习来理解用户、笔记和商品之间的联系；
# 3、创建，评测，使用模型帮助用户更快的发现属于TA的好东西。
#
# 我们希望你--
# 1、全日制计算机相关专业本科及以上学历；
# 2、熟练掌握或者深刻理解Java、C++、Python、Scala、Go其中一门或者多门语言；
# 3、对CS常见数据结构和算法有研究；
# 4、对处理、分析大量数据，以及建模有强烈兴趣，熟悉MapReduce，了解Hadoop、Spark系统；
# 5、有以下相关知识、经验：machine learning、information retrieval、 recommendation system、social network analysis；
# 6、积极而且有责任心。

# %% [markdown]
# ## 小米

# %% [markdown]
# ## 微软

# %% [markdown]
# ## 360（已投）

# %% [markdown]
# 分享到
# 机器学习算法工程师（BDG）
# 360集团
# 算法类
# 北京市·朝阳区
# 职位描述
# Hi，我们是360集团大数据产品事业部团队，我们的终极使命是让数据成就企业价值，让企业更快速，更可靠，更准确，更便捷的通过数据创造价值。你将在这里同来自海内外顶级大数据公司的优秀人才一起共事，加入我们吧，你将是一颗“量·新星”，如量子一般，在充满无限可能的宇宙中，释放自己能量，快速成长，冲击未来。
#
# 你的职责是：
#
# -    对海量业务数据进行分析和处理，能够从客户本身出发，运用AI能力，构建时序预测、异常检测、模式发现、根因分析等智能分析与工程落地；
#
# -    参与图算法的设计、实现、并实际应用于企业业务场景；
#
# -    利用离线和在线的图模式挖掘，如子图分析、社群发现、传播方法、Graph Eembedding等挖掘异常行为模式，并提供智能决策。
#
# 任职要求：
#
# 1、数学、计算机相关专业硕士及以上学历
#
# 2、扎实的编程技术，掌握C++,Java,python至少两门语言，熟悉主流的深度学习工具Tensorflow/pytorch
#
# 3、掌握常见的算法模型，包括但不限于KNN、ARIMA、prophet、LSTM、Bert等
#
# 4、掌握LPA、PageRank等基本图相关算法
#
# 5、熟悉图分析、图表征、GNN等算法模型的应用优先
#
# 6、了解Spark、GraphX或其他图处理计算框架优先

# %% [markdown]
# 机器学习算法实习生
# 360集团
# 算法类
# 上海市
# 职位描述
# 如果你想，让自己所构建的模型为数亿网民服务，360有——tb级的数据供你实验；
#
# 如果你想，做出对用户真正有帮助的推荐系统，360有——最好的平台让你发挥；
#
# 如果你想，在创造属于自己的数据时代，那么来360做数据挖掘吧！在这里，你可以：
#
# 1、学习和了解互联网广告业务知识以及相关产品背后的算法和策略；
#
# 2、参与设计和优化各种广告投放策略，包括CTR预测、广告召回算法、创意图文生成和优化等；
#
# 3、对海量数据进行分析和挖掘，使用或实现大数据机器学习算法解决业务问题。
#
# 任职要求：
#
# 1、熟悉机器学习、数据挖掘的基本理论和相关算法，有实践操作经验者优先；
#
# 2、优秀的编程能力，有数据结构和算法基础，熟练掌握至少一门编程语言（Python/Java/Scala）；
#
# 3、有较强的分析和解决问题的能力，持续学习新知识的能力和意愿；
#
# 4、沟通能力强，有优秀的团队合作意识。

# %% [markdown]
# ## 金山wps

# %% [markdown]
# 各位同学好，金山办公WPS是目前A股市值最高的软件企业，武汉金山办公作为金山办公建设中的第二总部，目前招聘前端开发实习生、服务端开发实习生、客户端开发实习生、软件测试实习生、C++实习生。实习地点：武汉市光谷APP广场。要求实习至少三个月以上，每周至少实习四天，具体岗位职责和任职要求请阅读简章。有意愿者请投递简历到邮箱：s_liuyuanxin@wps.cn。

# %% [markdown]
# ## 海康威视

# %% [markdown]
# ## [微众银行](https://mp.weixin.qq.com/s?__biz=MjM5MzY1OTk1Nw==&mid=2649973849&idx=1&sn=46b4446d76f22156398b69702088ec9a&chksm=be94690389e3e0155affe0137c9f3a9d64c5a87f6d4947af34a23c0058c7b858e3c2b654bd4b&mpshare=1&scene=23&srcid=0326KXwskUBgzimksDkPXzQm&sharer_sharetime=1616772854365&sharer_shareid=6456400ccc3de6db9f8b2f60b04226c7#rd)

# %% [markdown]
# 国内第一家网商银行招聘实习生，内推码LE065015

# %% [markdown]
# # 已投

# %% [markdown]
# ## 华为

# %% [markdown]
# - 岗位：算法工程师-研发算法
# - 要求：
#     - 1、具备人工智能AI算法、大数据算法、数据结构算法设计和开发能力；
#     - 2、具备前沿人工智能技术跟踪和业界趋势的跟踪和算法应用能力；
#     - 3、至少掌握Java/Python/C其中一种开发语言，掌握Hadoop开源工具使用更佳；
#     - 4、至少掌握一种数据挖掘工具和深度模型训练工具,如Tensorflow,caffe,matlab；
#     - 5、具备较强的动手实践能力,能够快速把想法用算法程序的实现；
#     - 6、具备挑战不可能的精神和创新意识，主动担责，攻坚破难；
#     - 7、具备良好的团队合作精神，善于沟通。
#
# -  4月   简历投递与筛选
#
# -  5月   面试启动（线上视频面试）
#
# - 6月实习offer发放与签约

# %% [markdown]
# ## 腾讯

# %% [markdown]
# 数据分析
#
# ![QQ%E6%88%AA%E5%9B%BE20210324095331.png](attachment:QQ%E6%88%AA%E5%9B%BE20210324095331.png)

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20210324094806.png](attachment:QQ%E6%88%AA%E5%9B%BE20210324094806.png)

# %% [markdown]
# ## 阿里

# %% [markdown]
# 国际事业部
#
# 算法工程师（机器学习）
#
# 已笔试

# %% [markdown]
# 部门巨多

# %% [markdown]
# ## 虎牙

# %% [markdown]
# 职位描述
# 岗位职责：
#
# 1、负责机器学习基本算法的开发与性能提升，涉及的问题包括但不限于：特征工程，大数据分析，分类聚类，数据挖掘，搜索排序，个性化推荐等；
#
# 2、推动机器学习在众多实际应用场景的落地。
#
#
#
# 任职要求：
#
# 1、2022届硕士或博士学历（优秀本科生亦可），人工智能、机器学习等专业，有顶会论文或实际业务落地经验者优先；
#
# 2、熟练掌握机器学习基本方法（如SVM, LR, 分类，回归，聚类，决策树，特征工程等）和应用（如数据挖掘，搜索排序，个性化推荐等）；
#
# 3、有较强的算法实现能力，熟练掌握 Python/C/C++ 编程，熟悉Linux 系统，Shell 编程；
#
# 4、优秀的分析问题和解决问题的能力，对解决具有挑战性的问题充满激情；
#
# 5、有较强的学术比赛或工程项目经验, 获得过重要代码竞赛的荣誉, 在重要数据集的Leaderboard上排名靠前, 或开源代码在github上产生较大影响者优先。
#
# 6、实习期不少于3个月，表现优秀者可获得虎牙2022届校招offer。

# %% [markdown]
# ## 美团

# %% [markdown]
# 机器学习/数据挖掘算法工程师
#
# 岗位职责：
# 在这里，你将通过机器学习、数据挖掘、深度/增强学习前沿技术对海量O2O数据进行洞察和预测，提高线下服务效率，优化线上用户体验，人和服务的高效连接潜力无限，帮助亿万用户吃得更好、生活更好；
# 在这里，你将从海量浏览和交易数据中不断抽象模式建立模型，一手保障商户在线营销可靠安全，另一手为消费者呈现有效评价提供优质服务，用技术提升消费质量；
# 在这里，你可以发挥你的算法天赋，在海量数据的平台上实践各种机器学习和挖掘算法，搜索、推荐、广告、调度、无人配送、风控、金融、ERP和智能化交互，为你提供最广阔的施展天地。
# 任职要求
# 岗位要求：
# 1.良好的数据结构和算法基础，具有较强的程序开发和分布式系统实现能力；
# 2.熟练掌握数据库设计原理，对NoSQL和分布式计算有理解和实践；
# 3.对概率论、机器学习和自然语言处理有一定的理论基础，在深度学习/增强学习/最优化等方向有理解或实践；
# 4.对数据敏感，思维逻辑清晰，对业务问题充满好奇，相信大数据背后的力量。
# 具备以下者优先：
# 1.具备相关行业互联网公司核心项目实习经验者优先；
# 2.发表过相关技术方向国际顶会或核心期刊一作论文者优先；
# 3.对大型开源软件项目有核心开发贡献者优先；
# 4.熟悉大数据技术（Hadoop、Spark、Storm等）者优先。
# 岗位亮点：
# 1.有海量的数据和复杂的生活服务真实落地场景；
# 2.与搜索、推荐、广告、物流调度、无人配送、风控、金融、ERP和智能交互方向的算法大牛一起学习工作；
# 3.做对社会有价值的事情，用自己的知识和才能帮助人们吃得更好、生活更好。

# %% [markdown]
# ## 网易互娱

# %% [markdown]
# 机器学习算法实习生
#
# 岗位描述
# 1、结合业务场景需求，开发优化深度学习框架，包括支持大规模稀疏化特征场景、支持大规模图神经网络应用场景、支持推荐系统推理性能优化场景等；
# 2、参与开发优化深度学习算法的工程实现，包括算法建模优化、训练性能优化、推理性能优化等，推动深度学习算法在业务场景的落地；
# 3、参与产品化开发工作，将框架能力与算法能力沉淀到内部深度学习平台，并且快速推广复用到更多业务场景。
# 岗位要求
# 1、熟练掌握C++/Python等编程语言，了解常见数据结构；
# 2、对Tensorflow/PyTorch/Graph-Learn/DGL/TensorFlow Serving等任意一种框架有深入理解，具备较好的定制开发能力；
# 3、对分布式系统、多核并行计算、GPU异构计算等系统有较好的理解；
# 4、熟悉基本的机器/深度学习算法；
# 5、具备扎实的工程编程能力，和较好的工程实现规范；
# 6、具备良好的跨团队合作和沟通能力，较强的抗压能力。
#
# 加分项：
# 1、具备深度学习框架核心模块开发、优化经验或有开源贡献者优先。
# 2、具备深度学习分布式、并行计算系统故障定位和性能优化经验者优先。
# 3、具备大数据系统开发经验者优先。
# 4、熟悉深度学习算法在推荐/广告等数据场景应用者优先。
# 5、具备深度学习框架和算法产品化经验者优先"

# %% [markdown]
# 数据挖掘实习生
#
# 岗位描述
# 1、搞懂用户，负责面向互联网的用户行为应用的调研和研究；
# 2、搞清楚算法，负责研究和设计具体挖掘方向的算法以及海量数据处理的优化算法；
# 3、搞明白自然语言，负责自然语言处理，分类，聚类和关联关系挖掘，语义关系挖掘。
# 岗位要求
# 我们希望你：
# 1、学的是计算机相关专业，硕士及以上学历；
# 2、熟悉数据挖掘或者信息检索领域的相关算法；
# 3、熟悉C/C++或者Java编程，熟悉Linux/Unix平台优先；
# 4、熟悉网络、多线程编程技术，帅气值加五分；
# 5、学习能力强，自我管理能力强，有较好的沟通交流能力；
# 6、具有信息检索、文本挖掘、机器学习、统计学等相关领域的同学，有海量数据处理和分析的经验的同学，加分加分加分。

# %% [markdown]
# ## 字节跳动

# %% [markdown]
# 机器学习实习生（可转正）已投递
# 北京
# 研发 - 机器学习
# 实习
# 职位描述
# 1、协助完成针对特定应用场景的机器学习模型设计，向业务线提供算法支持；
# 2、参与数据处理、模型搭建、性能优化、工程上线的部分工作；
# 3、分析已有模型的性能表现并提出可能的迭代方案；
# 4、机器学习、深度学习、计算机视觉前沿技术的研究；包括但不限于：对抗样的生成和防御，deepfake的生成和检测，机器学习中的隐私保护等。
# 职位要求
# 1、本科及以上学历，计算机相关专业；
# 2、有一定的机器学习、深度学习理论基础和实践经验；
# 3、熟练的编程能力，精通至少一门编程语言，如Python，C/C++等；
# 4、熟悉常用的机器学习算法、深度学习模型；熟练使用至少一种深度学习框架（如Pytorch，TensorFlow，Caffe，Keras，MxNet等）；
# 5、有良好的沟通能力，具有团队合作精神，优秀的逻辑分析能力和学习能力；
# 6、有在机器学习顶级期刊或会议（如ICML，NeurIPS，ICLR，CVPR，ICCV，ECCV，JMLR，TPAMI，IJCV等）发表经历者优先。

# %% [markdown]
# 想去番茄小说
#
# 暑期实习】客户端开发实习生-番茄小说
#
# 北京
# 研发 - 客户端
# 实习
# 2021春招项目
# 职位描述
# 团队介绍：番茄小说是今日头条在 2019 年全新推出的，面向网文热爱者的免费阅读产品，致力于为读者提供畅快不花钱的极致阅读体验。番茄小说拥有海量正版小说，涵盖青春、言情、玄幻、校园、仙侠、都市、悬疑等全部主流网文类型，以及大量热剧原著和经典出版物，支持用户看书听书。截至2020年4月，每日活跃用户超过1000万。
#
# 1、负责字节跳动番茄小说等多业务方向的客户端开发工作；
# 2、参与 APP 性能、体验优化及质量监控评估体系建设；
# 3、参与客户端基础组件及架构设计, 推进研发效率；
# 4、参与 Hybrid 容器搭建，插件、React Native 等动态技术调研。
# 职位要求
# 1、2022届获得本科及以上学历，计算机相关专业；
# 2、热爱计算机科学和互联网技术，对移动产品有浓厚兴趣；
# 3、扎实的数据结构和算法基础；精通至少一门编程语言，包括但不限于：Java、Objective-C、Swift、C、C++；
# 4、关注用户体验，能够积极把技术转化到用户体验改进上；
# 5、对新技术保持热情，具备良好的分析、解决问题的能力；
# 6、良好的沟通和团队协作能力、热爱技术、责任心强、能推动技术框架的落地使用；
# 7、每周工作至少4天，实习时间3个月起。

# %% [markdown]
# ## 百度

# %% [markdown]
# 工作职责:
# -研究数据挖掘或统计学习领域的前沿技术,并用于实际问题的解决和优化
#
# -大规模机器学习算法研究及并行化实现,为各种大规模机器学习应用研发核心技术
#
# -通过对数据的敏锐洞察,深入挖掘产品潜在价值和需求,进而提供更有价值的产品和服务,通过技术创新推动产品成长
#
# 职责要求:
# -热爱互联网，对技术研究和应用抱有浓厚的兴趣，有强烈的上进心和求知欲，善于学习和运用新知识
#
# -具有以下一个或多个领域的理论背景和实践经验：机器学习/数据挖掘/深度学习/信息检索/自然语言处理/机制设计/博弈论
#
# -至少精通一门编程语言，熟悉网络编程、多线程、分布式编程技术，对数据结构和算法设计有较为深刻的理解
#
# -良好的逻辑思维能力，对数据敏感，能够发现关键数据、抓住核心问题
#
# -较强的沟通能力和逻辑表达能力，具备良好的团队合作精神和主动沟通意识
#
# 具有以下条件者优先：
#
# -熟悉文本分类、聚类、机器翻译，有相关项目经验
#
# -熟悉海量数据处理、最优化算法、分布式计算或高性能并行计算，有相关项目经验
#
# -该岗位为实习岗位，面对2022年毕业的在校生
#
# -实习时间不少于3个月
