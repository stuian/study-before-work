# %% [markdown]
# # 投递和面试

# %% [markdown]
# ## 牛客网模拟笔试

# %% [markdown]
# 二叉树变平衡二叉树

# %% [markdown]
# ## 阿里笔试

# %% [markdown]
# 动态规划
#
# 0-1背包问题
#
# 牛客网，需要写输入

# %% [markdown]
# ## 美团笔试

# %% [markdown]
# 赛码：需要自己写输入输出
# 1、替换一个字符，使之成回文子串，或者值越小越好
# 2、

# %% [markdown]
# ## 腾讯数据分析一面

# %% [markdown]
# ## 360笔试

# %% [markdown]
# 赛码
# 位运算（异或）
# N个连成一条直线的宝藏，求获得的最多宝藏数量
